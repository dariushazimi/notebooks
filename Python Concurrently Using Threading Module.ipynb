# %%
# Lets look at some examples to really understand it.

# Why use threading?
# We want to use threading, when ever its going to speed up our program
# This speed up comes from running different tasks concurrently
# But keep in mind speedup is not guarnateed and it depends on what you are doing
# In this example we will run some sleep methods concurrently but then we will
# finish off with a real world example

# %%
import time

start = time.perf_counter()

def do_something():
    print('Sleeping 1 second...')
    time.sleep(1)
    print('Done Sleeping...')
    
    
do_something()

finish = time.perf_counter()

print(f'Finished in {round(finish-start, 2)} second(s)')
# Out:
# Sleeping 1 second...
# Done Sleeping...
# Finished in 1.01 second(s)

# %%
# if I want to run this function multiple times

import time

start = time.perf_counter()

def do_something():
    print('Sleeping 1 second...')
    time.sleep(1)
    print('Done Sleeping...')
    
    
do_something()
do_something()
do_something()
do_something()

finish = time.perf_counter()

print(f'Finished in {round(finish-start, 2)} second(s)')
# Out:
# Sleeping 1 second...
# Done Sleeping...
# Sleeping 1 second...
# Done Sleeping...
# Sleeping 1 second...
# Done Sleeping...
# Sleeping 1 second...
# Done Sleeping...
# Finished in 4.02 second(s)

# %%
# It takes over 4 sec to run these tasks.
# Lets see how we can run them concurrently
from IPython.display import Image
Image(filename='python-concurrency-1.png')

# running everything this way is called running it synchronously.
# and any time we are running code synchronously, it is not doing much on the cpu,
# rather just waiting around as shown below
# these are called CPU bound and IO bound tasks.
# CPU bound task are the ones that are crunching a lot of numbers and using the cput a lot.
# io bound tasks are like read and write to the file system

# %%
from IPython.display import Image
Image(filename='python-with-concurrency and threading.png')

# %%
# to be continued
