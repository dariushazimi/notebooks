# %% [markdown]
# # Common issues with Data
# - Reading files
# - Inconsistent column names
# - Missing values
# - Different Data types
# - Duplicate rows
# - other

# %% [markdown]
# # Reading Files

# %%
# UTF encoding
import pandas as pd
#source_file_url = "https://raw.....csv"

#df = pd.read_csv(source_file_url)
# if we just load the data as is, we get the following error:
# 'utf-8' codec can't decode byte 0xff in position 7: invalid start byte

# lets encode the file

# %%
df1 = pd.read_csv("unclean_data.csv", encoding="latin1")

# %%
# You can also open the file in an editor and do a save as with encoding utf8 
df1.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...
