# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.2'

# %%
myfile = pd.read_csv('olympics.csv', skiprows=4)
myfile.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Info give you the data type for each col and row
# Useful to find out if there are any NAN values in your series
myfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
# Lets see if there are any missing values in any of the column.
# apperently not
myfile.isnull().sum()
# Out:
# City            0
# Edition         0
# Sport           0
# Discipline      0
# Athlete         0
# NOC             0
# Gender          0
# Event           0
# Event_gender    0
# Medal           0
# dtype: int64

# %%
# if there was a column with a lot of missing values and we want to drop it, this is how we could do it.
print(myfile.shape)

# Drop the 'county_name' and 'state' columns
# myfile.drop(['county_name', 'state'], axis='columns', inplace=True)
# Out:
# (29216, 10)

# %%
myfile.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
myfile['City']
type(myfile.City)
# Out:
# pandas.core.series.Series

# %%
myfile[['City', 'Athlete','Medal']]
# Out:
#           City               Athlete   Medal
# 0       Athens         HAJOS, Alfred    Gold
# 1       Athens      HERSCHMANN, Otto  Silver
# 2       Athens     DRIVAS, Dimitrios  Bronze
# 3       Athens    MALOKINIS, Ioannis    Gold
# 4       Athens    CHASAPIS, Spiridon  Silver
# ...        ...                   ...     ...
# 29211  Beijing        ENGLICH, Mirko  Silver
# 29212  Beijing  MIZGAITIS, Mindaugas  Bronze
# 29213  Beijing       PATRIKEEV, Yuri  Bronze
# 29214  Beijing         LOPEZ, Mijain    Gold
# 29215  Beijing        BAROEV, Khasan  Silver
#
# [29216 rows x 3 columns]

# %%
type(myfile[['City', 'Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame

# %%
myfile.shape
# Out:
# (29216, 10)

# %%
# To just get the number of rows or columns
print("here are the rows ", myfile.shape[0])
print('here are the columns ', myfile.shape[1])
# Out:
# here are the rows  29216
# here are the columns  10

# %%
# head() and tail()
# by default you get the first 5 and last 5 rows
myfile.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# # Basic analysis
# series.value_count(normalize = False, sort=True, ascending=False, bins=None, dropna=True)
#
# Returns a series object counting all the UNQ values
# Note: the first value is the most reccuring element followed by the 2nd most re-occuring element and so on....
# Default is in desc order

# %%
myfile.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
myfile.Gender.value_counts(ascending=True)
type(myfile.Gender.value_counts(ascending=True))
# Out:
# pandas.core.series.Series

# %%
## sort_values

# %%
myfile.Athlete.sort_values()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
myfile.sort_values(['Edition', 'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# # Boolean Indexing AND &  OR  |   NOT ~

# %%
myfile.Medal == 'Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %% [markdown]
# # Dataframe
#
# To actually see which Ahtlete got the gold medal, we can use the dataframe

# %%
myfile[myfile['Medal']=='Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %% [markdown]
# ## Question: Find out all the Women athlete who won the gold medal

# %%
myfile[(myfile['Medal'] == 'Gold') & (myfile['Gender']=='Women') & (myfile['City'] == 'Beijing')]
# Out:
#           City  Edition          Sport       Discipline         Athlete  NOC  \
# 27178  Beijing     2008       Aquatics           Diving    CHEN, Ruolin  CHN
# 27184  Beijing     2008       Aquatics           Diving   GUO, Jingjing  CHN
# 27194  Beijing     2008       Aquatics           Diving    CHEN, Ruolin  CHN
# 27195  Beijing     2008       Aquatics           Diving       WANG, Xin  CHN
# 27206  Beijing     2008       Aquatics           Diving   GUO, Jingjing  CHN
# ...        ...      ...            ...              ...             ...  ...
# 29134  Beijing     2008  Weightlifting    Weightlifting        CAO, Lei  CHN
# 29147  Beijing     2008      Wrestling  Wrestling Free.    HUYNH, Carol  CAN
# 29155  Beijing     2008      Wrestling  Wrestling Free.  YOSHIDA, Saori  JPN
# 29163  Beijing     2008      Wrestling  Wrestling Free.     ICHO, Kaori  JPN
# 29171  Beijing     2008      Wrestling  Wrestling Free.      WANG, Jiao  CHN
#
# ...

# %%
myfile[(myfile['Medal'] == 'Gold') & (myfile['Gender']=='Women') & (myfile['City'] == 'Beijing')]
# Out:
#           City  Edition          Sport       Discipline         Athlete  NOC  \
# 27178  Beijing     2008       Aquatics           Diving    CHEN, Ruolin  CHN
# 27184  Beijing     2008       Aquatics           Diving   GUO, Jingjing  CHN
# 27194  Beijing     2008       Aquatics           Diving    CHEN, Ruolin  CHN
# 27195  Beijing     2008       Aquatics           Diving       WANG, Xin  CHN
# 27206  Beijing     2008       Aquatics           Diving   GUO, Jingjing  CHN
# ...        ...      ...            ...              ...             ...  ...
# 29134  Beijing     2008  Weightlifting    Weightlifting        CAO, Lei  CHN
# 29147  Beijing     2008      Wrestling  Wrestling Free.    HUYNH, Carol  CAN
# 29155  Beijing     2008      Wrestling  Wrestling Free.  YOSHIDA, Saori  JPN
# 29163  Beijing     2008      Wrestling  Wrestling Free.     ICHO, Kaori  JPN
# 29171  Beijing     2008      Wrestling  Wrestling Free.      WANG, Jiao  CHN
#
# ...

# %% [markdown]
# # String handling

# %%
myfile.Athlete.str.contains('Florence')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214    False
# 29215    False
# Name: Athlete, Length: 29216, dtype: bool

# %% [markdown]
# # To find out where this is actually true

# %%
myfile[myfile['Athlete'].str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# # Challenge Chap 4

# %% [markdown]
# Question 1: In which events did Jesse owens win a medal

# %%
myfile[myfile['Athlete']=='OWENS, Jesse']
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
jo = myfile[myfile['Athlete']=='OWENS, Jesse']
jo['Event'].value_counts()
# this will give all the events that Jesse was involved in
# Out:
# 200m            1
# 4x100m relay    1
# 100m            1
# long jump       1
# Name: Event, dtype: int64

# %% [markdown]
# Question 2: Which country has won the most men's gold medals iin singles badminton over the years?

# %%
myfile[(myfile['Medal'] =='Gold') & (myfile['Sport'] =='Badminton')]
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 20032  Barcelona     1992  Badminton  Badminton           PARK, Joo-Bong  KOR
# 20039  Barcelona     1992  Badminton  Badminton          CHUNG, So-Young  KOR
# 20040  Barcelona     1992  Badminton  Badminton         HWANG, Hae-Young  KOR
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 20049  Barcelona     1992  Badminton  Badminton            SUSANTI, Susi  INA
# 21771    Atlanta     1996  Badminton  Badminton     MAINAKY, Rexy Ronald  INA
# 21772    Atlanta     1996  Badminton  Badminton    SUBAGJA, Ricky Achmad  INA
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 21780    Atlanta     1996  Badminton  Badminton                  GE, Fei  CHN
# 21781    Atlanta     1996  Badminton  Badminton                  GU, Jun  CHN
# ...

# %%
most_medals=myfile[(myfile['Medal'] =='Gold') & (myfile['Sport'] =='Badminton')]
most_medals['NOC'].value_counts()
# Out:
# CHN    17
# KOR    11
# INA     9
# DEN     1
# Name: NOC, dtype: int64

# %% [markdown]
# Question 3: Which 3 countries have won the most medals in recent years (from 1984 to 2008)

# %%
myfile[(myfile['Edition'] >= 1984) & (myfile['Edition']< 2008)]
# Out:
#               City  Edition      Sport       Discipline  \
# 16592  Los Angeles     1984   Aquatics           Diving
# 16593  Los Angeles     1984   Aquatics           Diving
# 16594  Los Angeles     1984   Aquatics           Diving
# 16595  Los Angeles     1984   Aquatics           Diving
# 16596  Los Angeles     1984   Aquatics           Diving
# ...            ...      ...        ...              ...
# 27169       Athens     2004  Wrestling  Wrestling Gre-R
# 27170       Athens     2004  Wrestling  Wrestling Gre-R
# 27171       Athens     2004  Wrestling  Wrestling Gre-R
# 27172       Athens     2004  Wrestling  Wrestling Gre-R
# 27173       Athens     2004  Wrestling  Wrestling Gre-R
#
#                            Athlete  NOC Gender         Event Event_gender  \
# 16592               LI, Kong-Zheng  CHN    Men  10m platform            M
# 16593            LOUGANIS, Gregory  USA    Men  10m platform            M
# ...

# %%
# Now we can do a value_counts()
cn = myfile[(myfile['Edition'] >= 1984)]
cn['NOC'].value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
# Another way is to do it in one line
(myfile[(myfile['Edition'] >=1984) & (myfile['Edition']< 2008)])['NOC'].value_counts()
# Out:
# USA    1522
# AUS     613
# GER     590
# CHN     495
# RUS     495
#        ...
# ECU       1
# MKD       1
# CIV       1
# UGA       1
# URU       1
# Name: NOC, Length: 116, dtype: int64

# %% [markdown]
# Quesetion 4; Display the male gold meal winners for the 100m track and filed sprint event over the years.

# %%
myfile[(myfile['Gender']=='Men') & (myfile['Medal'] == 'Gold') & (myfile['Event']=='100m')]
# Out:
#                         City  Edition      Sport Discipline  \
# 13                    Athens     1896  Athletics  Athletics
# 231                    Paris     1900  Athletics  Athletics
# 737                 St Louis     1904  Athletics  Athletics
# 1191                  London     1908  Athletics  Athletics
# 2022               Stockholm     1912  Athletics  Athletics
# 2996                 Antwerp     1920  Athletics  Athletics
# 4236                   Paris     1924  Athletics  Athletics
# 5095               Amsterdam     1928  Athletics  Athletics
# 5806             Los Angeles     1932  Athletics  Athletics
# 6427                  Berlin     1936  Athletics  Athletics
# 7302                  London     1948  Athletics  Athletics
# 8121                Helsinki     1952  Athletics  Athletics
# 9009   Melbourne / Stockholm     1956  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# ...

# %%
gmh = myfile[(myfile['Gender']=='Men') & (myfile['Medal'] == 'Gold') & (myfile['Event']=='100m')]
gmh.sort_values('Edition', ascending = False)
# to only disply the columns we want we can add them as lists

gmh.sort_values('Edition', ascending = False)[['City', 'Edition', 'Athlete', 'Medal']]
# Out:
#                         City  Edition                Athlete Medal
# 27552                Beijing     2008            BOLT, Usain  Gold
# 25539                 Athens     2004         GATLIN, Justin  Gold
# 23521                 Sydney     2000        GREENE, Maurice  Gold
# 21598                Atlanta     1996        BAILEY, Donovan  Gold
# 19859              Barcelona     1992      CHRISTIE, Linford  Gold
# 18284                  Seoul     1988            LEWIS, Carl  Gold
# 16794            Los Angeles     1984            LEWIS, Carl  Gold
# 15374                 Moscow     1980           WELLS, Allan  Gold
# 14069               Montreal     1976       CRAWFORD, Hasely  Gold
# 12902                 Munich     1972         BORZOV, Valery  Gold
# 11865                 Mexico     1968       HINES, James Ray  Gold
# 10823                  Tokyo     1964          HAYES, Robert  Gold
# 9924                    Rome     1960            HARY, Armin  Gold
# ...

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# plot(kind = 'line') Best for tracking changes over a period of time
# plot(kind = 'bar') Best for comparing between diff group
# plot(kind = 'barh') almost identical but axis have been flipped
# plot(kind = 'pie') Best for comparing parts of whole (they don't show changes over time)

# %%
# What were the differnt sports in the first olympics? Plot them using diff graphs.

# %%
fo = myfile[myfile['Edition']==1896]

# %%
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Line plot

# %%
fo['Sport'].value_counts()
# Out:
# Gymnastics       45
# Athletics        37
# Cycling          16
# Shooting         15
# Aquatics         11
# Tennis           10
# Fencing           8
# Weightlifting     6
# Wrestling         3
# Name: Sport, dtype: int64

# %%
# we can now chain the plot command to show all the events played in the first olympics

# %%
fo['Sport'].value_counts().plot(kind='line')

# %%
# To surpress the <matplotlib line below the code above, just add a semicolon to the end of the line

# %%
fo['Sport'].value_counts().plot();

# %%
fo['Sport'].value_counts().plot(kind='bar');

# %%
fo['Sport'].value_counts().plot(kind='barh');

# %%
fo['Sport'].value_counts().plot(kind='pie');

# %% [markdown]
# # 6.5-24 Color Plots
# plot('color=red')

# %%
fo['Sport'].value_counts().plot(color='plum');

# %%
fo['Sport'].value_counts().plot(kind='bar', color='purple');

# %%
# Figure Size

# %%
fo['Sport'].value_counts().plot();

# %%
# To fix the issue with Axis and labels

# %%
fo['Sport'].value_counts().plot(figsize=(10, 3));

# %% [markdown]
# # Colormaps
# Classes of colormaps
# Sequential = used for ordering, there is a change in lightness of the color
# Diverging: should be used when the data is divergaing around the middle value
# Qualitative: should be used to represent information when the data doesn't have any ordering and it is often misc colors

# %%
fo['Sport'].value_counts().plot(kind='pie', colormap='Pastel1');

# %% [markdown]
# # Seaborn -Rich beutiful plots
# It is a visualiztion lib based on matplot lib
# It produces beutifull stats graphs and works nicely with pandas

# %% [markdown]
# # When to use seaborn vs matplotlib
# Matplotlib: short scripts and working in conjunction with pyplot or - simple plot types like line, bar, plot
# Seaborn: When dealing with statistical data or categorical data, or requiring moe advanced plots

# %%
import seaborn as sns

# %% [markdown]
# Question: How many medals have been won by the men and women in the history of olympics?
#     How many gold, silver and bronze were won for each men and women gender?

# %%
sns.countplot(x='Medal', data = myfile);

# %%
# To show the breakdown for each gender
sns.countplot(x='Medal', data= myfile, hue='Gender');

# %% [markdown]
# # Chapter 5 Challenge

# %% [markdown]
# Q1: Plot the number of medal achieved by the chinese team (men and women)in Beijing 2008 using Matplotlib and Seaborn

# %%
myfile[(myfile['City'] == 'Beijing') & (myfile['Edition']==2008)]
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving             WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
mw=myfile[(myfile['NOC'] == 'CHN') & (myfile['Edition']==2008)]
mw.head()
# Out:
#           City  Edition     Sport Discipline       Athlete  NOC Gender  \
# 27176  Beijing     2008  Aquatics     Diving   ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving     WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving  CHEN, Ruolin  CHN  Women
# 27180  Beijing     2008  Aquatics     Diving      QIN, Kai  CHN    Men
# 27181  Beijing     2008  Aquatics     Diving     HE, Chong  CHN    Men
#
#                 Event Event_gender   Medal
# 27176    10m platform            M  Silver
# 27177    10m platform            W  Bronze
# 27178    10m platform            W    Gold
# 27180  3m springboard            M  Bronze
# 27181  3m springboard            M    Gold

# %%
# to get the men and women
mw['Gender'].value_counts()
# Out:
# Women    128
# Men       56
# Name: Gender, dtype: int64

# %%
mw['Gender'].value_counts().plot(kind='bar');

# %%
# using seaborn
sns.countplot(data=mw, x ='Gender');

# %%
sns.countplot(data=mw, x ='Gender', palette='bwr');

# %%
Q2: How can you use colormaps to give the data more meaning?
# Out:
# Object `meaning` not found.

# %%
sns.countplot(data=mw, x ='Gender', palette='bwr');

# %%
Q3: Plot the number of gold, silver, and bronze medal for each gender
# Out:
#   File "<ipython-input-66-98172237493c>", line 1
#     Q3: Plot the number of gold, silver, and bronze medal for each gender
#                ^
# SyntaxError: invalid syntax

# %%
sns.countplot(data=mw, x ='Medal', hue='Gender');

# %%
# Q4: How can you give the data more meaning? is there anything else you can change to make it more intuitive?
sns.countplot(data=mw, x ='Medal', hue='Gender', palette='bwr');

# %%
# to change the order
# Q4: How can you give the data more meaning? is there anything else you can change to make it more intuitive
sns.countplot(data=mw, x ='Medal', hue='Gender', palette='bwr', order=['Gold', 'Silver', 'Bronze']);

# %%
# Indexes
The index object is an immutable array
Indexes allow s you to access a row or colum
# Out:
#   File "<ipython-input-70-0b4edcd6b561>", line 2
#     The index object is an immutable array
#             ^
# SyntaxError: invalid syntax

# %%
oo = pd.read_csv('olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
type(oo.index)
# note: index has its own type, it is not a series or a dataframe
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oo.index[100]
# Out:
# 100

# %%
# indexes are immutable
oo.index[100] = 5 # gives an error, you can't change them
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-6ad68f2f774f> in <module>
#       1 # indexes are immutable
# ----> 2 oo.index[100] = 5 # gives an error, you can't change them
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    3907
#    3908     def __setitem__(self, key, value):
# -> 3909         raise TypeError("Index does not support mutable operations")
#    3910
#    3911     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
# set_index()
Allows us to specify which series will be the index

# %%
# to set Athlete as the index one way is to:
oo.set_index('Athlete')
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# ...

# %%
# lets confirm that infact Athlete is our index but we can see that there is actually another index
# we can see that the dataframe has reverted back to the original index.
# we need to specify inplace=True
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete', inplace=True)

# %%
oo.head()
# you can see that it has maintained the new index
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
# lets reset the index
oo.reset_index(inplace=True)

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Another way to set the index,is to copy the dataframe and save it
ath = oo.set_index('Athlete')
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
# reset_index()
returns the dataframe to its original integer based index
# Out:
#   File "<ipython-input-82-8b2cceffbaef>", line 2
#     returns the dataframe to its original integer based index
#               ^
# SyntaxError: invalid syntax

# %%
# lets reset the ath dataframe so that is set back to the integer as index

# %%
ath.reset_index(inplace=True)
ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# sort_index()
When you have a large dataset, this improves the speed when searching
# Out:
#   File "<ipython-input-85-43db0454cc0f>", line 2
#     When you have a large dataset, this improves the speed when searching
#            ^
# SyntaxError: invalid syntax

# %%
ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath.set_index('Athlete', inplace=True)
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True)

# %%
ath.head()
# Out:
#                              City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
#
#                          Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar                Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian       Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian       Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes    Men   team competition            M    Gold

# %%
ath.sort_index(inplace=True, ascending=False)

# %%
ath.head()
# Umlats show up before the Z since our standard ending gives a lower value to these characters. If you have special char, you have to take that into account.
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze

# %% [markdown]
# # loc[ ]
# It is a label based indexer for selection by label

# %% [markdown]
# To Search the dataframe by athelete name we can

# %%
oo.head()
# Tip  to slice the dataframe
oo.loc[2:10:2, ['Athlete', 'Gender']]
# Out:
#                   Athlete Gender
# 2       DRIVAS, Dimitrios    Men
# 4      CHASAPIS, Spiridon    Men
# 6           HAJOS, Alfred    Men
# 8   CHOROPHAS, Efstathios    Men
# 10      PEPANOS, Antonios    Men

# %% [markdown]
# To search by Athlete name,
# 1. Set the index to Athlete name
# 2. use loc label to find

# %%
oo.set_index('Athlete', inplace=True)
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
oo.reset_index(inplace=True)

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# traditionally we would do this

# %%
oo.loc[oo['Athlete']=='BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %% [markdown]
# # iloc
# We are doing selection by integer position based

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.iloc[1700]
# Out:
# Athlete         RABOT, Pierre
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: 1700, dtype: object

# %%
# we can also use a list of integers
oo.iloc[[1542,2390,6000,15000]]
# Out:
#                         Athlete         City  Edition       Sport  \
# 1542     DUCKETT, Richard Louis       London     1908    Lacrosse
# 2390         SAASTAMOINEN, Eino    Stockholm     1912  Gymnastics
# 6000            AGOSTONI, Carlo  Los Angeles     1932     Fencing
# 15000  JENSEN, Poul Richard Hoj     Montreal     1976     Sailing
#
#         Discipline  NOC Gender                                    Event  \
# 1542      Lacrosse  CAN    Men                                 lacrosse
# 2390   Artistic G.  FIN    Men                        team, free system
# 6000       Fencing  ITA    Men                          épée individual
# 15000      Sailing  DEN    Men  fleet/match race keelboat open (Soling)
#
#       Event_gender   Medal
# 1542             M    Gold
# 2390             M  Silver
# 6000             M  Bronze
# 15000            X    Gold

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.iloc[1:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %% [markdown]
# # Challenge chap 6

# %% [markdown]
# q1: Plot the total number of medals awarded at each olympic games througout history
# q2: which countries did not win a medal in the 2008 Olypics? How many countries were there?

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo['Edition'].value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo['Edition'].value_counts().plot();

# %% [markdown]
# # What is wrong here?
# Lets look at the value_counts object

# %%
type(oo['Edition'].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# That mean when I do value_count, the first column is the index and the 2nd col are the values for that index
# and part of the problem is that the index is not sorted.

# %%
oo['Edition'].value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
So lets first sort the index
# Out:
#   File "<ipython-input-122-be2de32aaadd>", line 1
#     So lets first sort the index
#           ^
# SyntaxError: invalid syntax

# %%
oo.Edition.value_counts().sort_index()
# Out:
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# Name: Edition, dtype: int64

# %%
oo.Edition.value_counts().sort_index().plot()

# %%
# Which countries did not win a medal in 2008 and how many countries were thre?
lo = oo[oo.Edition ==2008]
lo
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 27174        GALPERIN, Gleb  Beijing     2008   Aquatics           Diving
# 27175      MITCHAM, Matthew  Beijing     2008   Aquatics           Diving
# 27176           ZHOU, Luxin  Beijing     2008   Aquatics           Diving
# 27177             WANG, Xin  Beijing     2008   Aquatics           Diving
# 27178          CHEN, Ruolin  Beijing     2008   Aquatics           Diving
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
# Lets use the other csv file that has the data per country
noc = pd.read_csv('Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
# since I have not examined this file before, I want to know if there is a diff between the col
# country and country.1
noc['Country']  != noc['Country.1']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# Length: 201, dtype: bool

# %%
# Lets display the result 
noc[noc['Country']  != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %% [markdown]
# Considering this is empty, they are both equal
# Lets set the index to the Olypic committee code

# %%
noc.set_index('Int Olympic Committee code', inplace=True)
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
# Now we need a unq list of countries

# %%
medals_2008 =lo['NOC'].value_counts()
medals_2008.head()
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# Name: NOC, dtype: int64

# %%
noc['medals_2008'] = medals_2008

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medals_2008
# Int Olympic Committee code
# AFG                                 1.0
# ALB                                 NaN
# ALG                                 2.0
# ASA                                 NaN
# AND                                 NaN

# %%
# where there is a NaN, the country did not have a medal
noc['medals_2008'].isnull()
# Out:
# Int Olympic Committee code
# AFG    False
# ALB     True
# ALG    False
# ASA     True
# AND     True
#        ...
# VIE    False
# ISV     True
# YEM     True
# ZAM     True
# ZIM    False
# Name: medals_2008, Length: 201, dtype: bool

# %%
# to get a dataframe of that
noc[noc['medals_2008'].isnull()].sort_index()
# Out:
#                                                      Country ISO code  \
# Int Olympic Committee code
# AHO                                    Netherlands Antilles*       AN
# ALB                                                  Albania       AL
# AND                                                  Andorra       AD
# ANG                                                   Angola       AO
# ANT                                      Antigua and Barbuda       AG
# ...                                                      ...      ...
# URU                                                  Uruguay       UY
# VAN                                                  Vanuatu       VU
# VIN                         Saint Vincent and the Grenadines       VC
# YEM                                                    Yemen       YE
# ZAM                                                   Zambia       ZM
#
#                                                    Country.1  medals_2008
# ...

# %%
# Chap 8 - Groupby

# %%
oo = pd.read_csv('olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.groupby('Edition')

# %%
# lets see what type this group by object is
type(oo.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
# to see how things are grouped, lets put them in a list

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896,
#          City  Edition          Sport       Discipline  \
#   0    Athens     1896       Aquatics         Swimming
#   1    Athens     1896       Aquatics         Swimming
#   2    Athens     1896       Aquatics         Swimming
#   3    Athens     1896       Aquatics         Swimming
#   4    Athens     1896       Aquatics         Swimming
#   ..      ...      ...            ...              ...
#   146  Athens     1896  Weightlifting    Weightlifting
#   147  Athens     1896  Weightlifting    Weightlifting
#   148  Athens     1896      Wrestling  Wrestling Gre-R
#   149  Athens     1896      Wrestling  Wrestling Gre-R
#   150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                         Athlete  NOC Gender                        Event  \
#   0               HAJOS, Alfred  HUN    Men               100m freestyle
#   1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# ...

# %%
# iterating through a group

# %%
for k, v in oo.groupby('Edition'):
    print(k)
    print(v)
# Out:
# 1896
#        City  Edition          Sport       Discipline  \
# 0    Athens     1896       Aquatics         Swimming
# 1    Athens     1896       Aquatics         Swimming
# 2    Athens     1896       Aquatics         Swimming
# 3    Athens     1896       Aquatics         Swimming
# 4    Athens     1896       Aquatics         Swimming
# ..      ...      ...            ...              ...
# 146  Athens     1896  Weightlifting    Weightlifting
# 147  Athens     1896  Weightlifting    Weightlifting
# 148  Athens     1896      Wrestling  Wrestling Gre-R
# 149  Athens     1896      Wrestling  Wrestling Gre-R
# 150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                       Athlete  NOC Gender                        Event  \
# 0               HAJOS, Alfred  HUN    Men               100m freestyle
# 1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# 2           DRIVAS, Dimitrios  GRE    Men   100m freestyle for sailors
# ...

# %%
# lets confirm what type each of these groups are:
type(v)
# and you can see that infact the values are df.
# Out:
# pandas.core.frame.DataFrame

# %%
# Groupby computations
Groupby.size(),

# %%
# to get the count of that group
oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %% [markdown]
# # agg()

# %%
oo.groupby(['Edition','NOC', 'Medal' ]).agg(['min', 'max', 'count'])
# Out:
#                        City                         Sport                 \
#                         min      max count            min            max
# Edition NOC Medal
# 1896    AUS Gold     Athens   Athens     2      Athletics      Athletics
#         AUT Bronze   Athens   Athens     2        Cycling        Cycling
#             Gold     Athens   Athens     2       Aquatics        Cycling
#             Silver   Athens   Athens     1       Aquatics       Aquatics
#         DEN Bronze   Athens   Athens     3        Fencing       Shooting
# ...                     ...      ...   ...            ...            ...
# 2008    UZB Silver  Beijing  Beijing     2           Judo      Wrestling
#         VEN Bronze  Beijing  Beijing     1      Taekwondo      Taekwondo
#         VIE Silver  Beijing  Beijing     1  Weightlifting  Weightlifting
#         ZIM Gold    Beijing  Beijing     1       Aquatics       Aquatics
#             Silver  Beijing  Beijing     3       Aquatics       Aquatics
#
# ...

# %%
oo.groupby(['Edition','NOC', 'Medal' ]).agg('count')
# Out:
#                     City  Sport  Discipline  Athlete  Gender  Event  \
# Edition NOC Medal
# 1896    AUS Gold       2      2           2        2       2      2
#         AUT Bronze     2      2           2        2       2      2
#             Gold       2      2           2        2       2      2
#             Silver     1      1           1        1       1      1
#         DEN Bronze     3      3           3        3       3      3
# ...                  ...    ...         ...      ...     ...    ...
# 2008    UZB Silver     2      2           2        2       2      2
#         VEN Bronze     1      1           1        1       1      1
#         VIE Silver     1      1           1        1       1      1
#         ZIM Gold       1      1           1        1       1      1
#             Silver     3      3           3        3       3      3
#
#                     Event_gender
# Edition NOC Medal
# 1896    AUS Gold               2
#         AUT Bronze             2
# ...

# %%
oo.groupby(['Edition','NOC', 'Medal' ]).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %%
# dictionary like structure
oo.groupby(['Edition','NOC', 'Medal' ]).agg({'Edition':['min', 'max', 'count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
oo.loc[oo['Athlete'] == 'LEWIS, Carl'].groupby('Athlete').agg({'Edition':[ 'min', 'max', 'count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %% [markdown]
# # Chap 8 Challenge

# %% [markdown]
# q1: Using groupby() plot the total number of medals awarded at
#     each of the olympic games throughout history
#
# q2: Create a list showing the total number of medals won for each country over the history of the olympics.
#     for each country, include the year of the first and most recent olympic medals wins

# %%
import pandas as pd

# %%
oo = pd.read_csv('olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.groupby('Edition').size().plot();

# %%
oo.groupby('NOC').agg(['count', 'min', 'max'])
# Out:
#      City                         Edition             Sport             \
#     count        min          max   count   min   max count        min
# NOC
# AFG     1    Beijing      Beijing       1  2008  2008     1  Taekwondo
# AHO     1      Seoul        Seoul       1  1988  1988     1    Sailing
# ALG    14    Atlanta       Sydney      14  1984  2008    14  Athletics
# ANZ    29     London    Stockholm      29  1908  1912    29   Aquatics
# ARG   239  Amsterdam        Tokyo     239  1924  2008   239   Aquatics
# ..    ...        ...          ...     ...   ...   ...   ...        ...
# VIE     2    Beijing       Sydney       2  2000  2008     2  Taekwondo
# YUG   435  Amsterdam        Tokyo     435  1924  2000   435   Aquatics
# ZAM     2    Atlanta  Los Angeles       2  1984  1996     2  Athletics
# ZIM    23     Athens       Moscow      23  1980  2008    23   Aquatics
# ZZX    48     Athens     St Louis      48  1896  1904    48  Athletics
#
# ...

# %%
# since the Edition field is the most usefull one, lets use the dictionary to get more info on the 
# edition field.

# %%
oo.groupby('NOC').agg({'Edition' : ['count', 'min', 'max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %%
# Stack and Unstack
oo = pd.read_csv('olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
## Athletes winning medals in Beijing olympics 100m or 200m track event.
oo[oo['Edition'] == 2008]
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving             WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
mw = oo[(oo['Edition'] == 2008)  & ( ( oo['Event'] == '100m') | (oo['Event'] == '200m')  ) ]

mw
# Out:
#           City  Edition      Sport Discipline                   Athlete  NOC  \
# 27551  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27552  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27553  Beijing     2008  Athletics  Athletics         THOMPSON, Richard  TRI
# 27554  Beijing     2008  Athletics  Athletics        FRASER, Shelly-ann  JAM
# 27555  Beijing     2008  Athletics  Athletics          SIMPSON, Sherone  JAM
# 27556  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27569  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27570  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27571  Beijing     2008  Athletics  Athletics           CRAWFORD, Shawn  USA
# 27572  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27573  Beijing     2008  Athletics  Athletics  CAMPBELL-BROWN, Veronica  JAM
# ...

# %%
g= mw.groupby(['NOC', 'Gender', 'Discipline', 'Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
g.unstack(['Discipline', 'Gender'])
# Out:
# Discipline Athletics
# Gender           Men Women
# NOC Event
# JAM 100m         1.0   3.0
#     200m         1.0   2.0
# TRI 100m         1.0   NaN
# USA 100m         1.0   NaN
#     200m         2.0   1.0

# %%
g.unstack(['Discipline', 'Event'])
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
# Stacking
stack function returns a df or series with a new inner most level of rows
Stacking gives you a taller dataframe

# %%
df= g.unstack(['Discipline', 'Event'])
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
df.stack('Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
# Unstack - getting a wider a dataframe

# %%
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
df.unstack('Gender')
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
# Challenge - Chap 9

# %%
Q1: Plot the number of gold medals won by the US male and 
    female atheletes throughout the history of the Olympics
    
Q2: Plot the 5 athletes who have won the most gold medasl over the history of the olymipcs. 
    When there is a tie, consider the number of silver medals, and then bronze medals.
# Out:
#   File "<ipython-input-256-52634e508c6e>", line 1
#     Q1: Plot the number of gold medals won by the US male and
#                ^
# SyntaxError: invalid syntax

# %%
gu = oo[(oo['NOC']=='USA') &( oo['Medal']== 'Gold')]

# %%
gu.groupby(['Edition', 'Gender']).size()
# Out:
# Edition  Gender
# 1896     Men        11
# 1900     Men        26
#          Women       1
# 1904     Men       140
#          Women       6
# 1908     Men        34
# 1912     Men        45
# 1920     Men       103
#          Women       7
# 1924     Men        95
#          Women      15
# 1928     Men        34
#          Women       9
# 1932     Men        61
#          Women      17
# 1936     Men        44
#          Women       7
# 1948     Men        75
#          Women       8
# 1952     Men        72
#          Women       7
# 1956     Men        57
#          Women       4
# 1960     Men        51
#          Women      17
# 1964     Men        63
#          Women      15
# 1968     Men        59
#          Women      24
# 1972     Men        37
#          Women      16
# 1976     Men        56
#          Women       7
# 1984     Men       106
#          Women      62
# 1988     Men        49
#          Women      28
# 1992     Men        57
#          Women      32
# ...

# %%
gu.groupby(['Edition', 'Gender']).size().unstack('Gender', fill_value=0).plot();

# %%
oo.groupby(['Athlete', 'Medal']).size()
# Out:
# Athlete                    Medal
# AABYE, Edgar               Gold      1
# AALTONEN, Arvo Ossian      Bronze    2
# AALTONEN, Paavo Johannes   Bronze    2
#                            Gold      3
# AAMODT, Ragnhild           Gold      1
#                                     ..
# ÖSTERVOLD, Kristian Olsen  Gold      1
# ÖSTERVOLD, Ole Olsen       Gold      1
# ÖSTMO, Ole                 Bronze    2
#                            Silver    2
# ÖSTRAND, Per-Olof          Bronze    1
# Length: 25127, dtype: int64

# %%
oo.groupby(['Athlete', 'Medal']).size().unstack('Medal', fill_value=0)
# Out:
# Medal                      Bronze  Gold  Silver
# Athlete
# AABYE, Edgar                    0     1       0
# AALTONEN, Arvo Ossian           2     0       0
# AALTONEN, Paavo Johannes        2     3       0
# AAMODT, Ragnhild                0     1       0
# AANING, Alf Lied                0     0       1
# ...                           ...   ...     ...
# ÖSTERVOLD, Jan Olsen            0     1       0
# ÖSTERVOLD, Kristian Olsen       0     1       0
# ÖSTERVOLD, Ole Olsen            0     1       0
# ÖSTMO, Ole                      2     0       2
# ÖSTRAND, Per-Olof               1     0       0
#
# [21413 rows x 3 columns]

# %% [markdown]
# ## To find out the athlete who have won the most gold you have to first sort them . Since the list above is not sorted

# %%
g = oo.groupby(['Athlete', 'Medal']).size().unstack('Medal', fill_value=0)  
g.sort_values(['Gold', 'Silver', 'Bronze'], ascending = False)
# Out:
# Medal                Bronze  Gold  Silver
# Athlete
# PHELPS, Michael           2    14       0
# LATYNINA, Larisa          4     9       5
# NURMI, Paavo              0     9       3
# SPITZ, Mark               1     9       1
# LEWIS, Carl               0     9       1
# ...                     ...   ...     ...
# ZYCH, Boguslaw            1     0       0
# ZÄHRINGER, Klaus          1     0       0
# ZÜHLKE, Steffen           1     0       0
# ÖRSTED, Hans-Henrik       1     0       0
# ÖSTRAND, Per-Olof         1     0       0
#
# [21413 rows x 3 columns]

# %%
# to sort it by gold, silver and bronze
g.sort_values(['Gold', 'Silver', 'Bronze'], 
              ascending = False)[['Gold', 
                                  'Silver',
                                  'Bronze']].head()
# Out:
# Medal             Gold  Silver  Bronze
# Athlete
# PHELPS, Michael     14       0       2
# LATYNINA, Larisa     9       5       4
# NURMI, Paavo         9       3       0
# SPITZ, Mark          9       1       1
# LEWIS, Carl          9       1       0

# %%
# to sort it by gold, silver and bronze
g.sort_values(['Gold', 'Silver', 'Bronze'], 
              ascending = False)[['Gold', 
                                  'Silver',
                                  'Bronze']].head().plot(kind='bar');

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# Using the Olympic dataset, present a sumamry of teh total medals won by countries in 2008 Olympics

# %%
oo = pd.read_csv('olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
mwon = oo[oo['Edition'] == 2008]
mwon.groupby(['NOC', 'Medal']).size().unstack('Medal', 
                                              fill_value=0)
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# AFG         1     0       0
# ALG         1     0       1
# ARG        31    20       0
# ARM         6     0       0
# AUS        76    31      42
# ..        ...   ...     ...
# USA        81   125     109
# UZB         3     1       2
# VEN         1     0       0
# VIE         0     0       1
# ZIM         0     1       3
#
# [86 rows x 3 columns]

# %%
smw = mwon.groupby(['NOC', 'Medal']).size().unstack('Medal', 
                                              fill_value=0)
smw.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# USA        81   125     109
# CHN        57    74      53
# RUS        56    43      44
# GER        43    42      16
# KOR        26    41      11
# ..        ...   ...     ...
# ISR         1     0       0
# MDA         1     0       0
# MRI         1     0       0
# TOG         1     0       0
# VEN         1     0       0
#
# [86 rows x 3 columns]

# %%
slist = smw.sort_values(['Gold', 'Silver', 'Bronze'], 
                ascending=False)[['Gold', 'Silver', 'Bronze']]

slist
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
smw.sort_values(['Gold', 'Silver', 'Bronze'], 
                ascending=False)[['Gold', 'Silver', 
                                  'Bronze']].head(5).plot(kind='bar')

# %%
# Another Method to plot it using heatmap

# %%
g = smw.sort_values(['Gold', 'Silver', 'Bronze'], 
                ascending=False)[['Gold', 'Silver', 'Bronze']]

g
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
sns.heatmap(g)

# %%
# lets swap the axis

# %%
g = g.transpose()

# %%
g
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN  ...  VIE  ARM  TPE  \
# Medal                                                     ...
# Gold    125   74   43   42   41   40   31   31   25   23  ...    0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11  ...    1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17  ...    0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
# lets make the figure bigger
plt.figure(figsize=(16,5))
sns.heatmap(g)

# %% [markdown]
# # Creating your own color map

# %%
g = mwon.groupby(['NOC', 'Medal']).size().unstack('Medal', 
                                              fill_value=0)
g.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# USA        81   125     109
# CHN        57    74      53
# RUS        56    43      44
# GER        43    42      16
# KOR        26    41      11
# ..        ...   ...     ...
# ISR         1     0       0
# MDA         1     0       0
# MRI         1     0       0
# TOG         1     0       0
# VEN         1     0       0
#
# [86 rows x 3 columns]

# %% [markdown]
# Let look at this questions again:
# Q2: Plot the 5 athletes who have won the most gold medasl over the history of the olymipcs.
#     When there is a tie, consider the number of silver medals, and then bronze medals.

# %%
g = oo.groupby(['Athlete', 'Medal']).size()
# here we have grouped by athlete and the type of medal they have won.
g
# Out:
# Athlete                    Medal
# AABYE, Edgar               Gold      1
# AALTONEN, Arvo Ossian      Bronze    2
# AALTONEN, Paavo Johannes   Bronze    2
#                            Gold      3
# AAMODT, Ragnhild           Gold      1
#                                     ..
# ÖSTERVOLD, Kristian Olsen  Gold      1
# ÖSTERVOLD, Ole Olsen       Gold      1
# ÖSTMO, Ole                 Bronze    2
#                            Silver    2
# ÖSTRAND, Per-Olof          Bronze    1
# Length: 25127, dtype: int64

# %%
g = g.unstack('Medal', fill_value=0)

# %%
g.sort_values(['Gold', 'Silver', 'Bronze'],
              ascending=False)[['Gold', 'Silver', 'Bronze']].head().plot(kind='bar')

# %%
# To create own own color map we would have to create a listed color map

# %%
from matplotlib.colors import ListedColormap
# to see the default color pallet

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.palplot(sns.color_palette())

# %%
# let create a list for our color pallete
gsb = ['#dbb40c', '#c5c9c7', '#a87900']
sns.palplot(sns.color_palette(gsb))

# %%
my_gsb = ListedColormap(sns.color_palette(gsb))

# %%
# Now lets apply this new color map to the code that we had ealier.
g = oo.groupby(['Athlete', 'Medal']).size().unstack('Medal', fill_value=0)
g = g.sort_values(['Gold', 'Silver', 'Bronze'],
              ascending=False)[['Gold', 'Silver', 'Bronze']].head()
g = g.plot(kind='bar', colormap = my_gsb);
g;

# %% [markdown]
# # Challenge - Final
# ## Chap 11 - 50

# %% [markdown]
# In every olympics, which US athlete has won the most total number of medals? Include the athlete's discipline.

# %%
oo.groupby(['Athlete', 'Medal']).size().unstack('Medal')
# Out:
# Medal                      Bronze  Gold  Silver
# Athlete
# AABYE, Edgar                  NaN   1.0     NaN
# AALTONEN, Arvo Ossian         2.0   NaN     NaN
# AALTONEN, Paavo Johannes      2.0   3.0     NaN
# AAMODT, Ragnhild              NaN   1.0     NaN
# AANING, Alf Lied              NaN   NaN     1.0
# ...                           ...   ...     ...
# ÖSTERVOLD, Jan Olsen          NaN   1.0     NaN
# ÖSTERVOLD, Kristian Olsen     NaN   1.0     NaN
# ÖSTERVOLD, Ole Olsen          NaN   1.0     NaN
# ÖSTMO, Ole                    2.0   NaN     2.0
# ÖSTRAND, Per-Olof             1.0   NaN     NaN
#
# [21413 rows x 3 columns]

# %%
# Lets examine the dataset and see if there any missing values
oo.isnull().sum()
# Out:
# City            0
# Edition         0
# Sport           0
# Discipline      0
# Athlete         0
# NOC             0
# Gender          0
# Event           0
# Event_gender    0
# Medal           0
# dtype: int64

# %%
# Count the number of missing values in each column
# print(ri.isnull().sum())

# Drop all rows that are missing 'driver_gender'
# ri.dropna(subset=['driver_gender'], inplace=True)

# Count the number of missing values in each column (again)
# print(ri.isnull().sum())

# Examine the shape of the DataFrame
# print(ri.shape)
oo.shape
# Out:
# (29216, 10)

# %%
oo['newcol'] = oo['City'] + oo['NOC']

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal     newcol
# 0              100m freestyle            M    Gold  AthensHUN
# 1              100m freestyle            M  Silver  AthensAUT
# 2  100m freestyle for sailors            M  Bronze  AthensGRE
# 3  100m freestyle for sailors            M    Gold  AthensGRE
# 4  100m freestyle for sailors            M  Silver  AthensGRE

# %%
# Now lets drop all rows the missing value for newcol
oo.dropna(subset=['newcol'], inplace=True)
# this won't make any changes in our case since all rows have value for newcol

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal     newcol
# 0              100m freestyle            M    Gold  AthensHUN
# 1              100m freestyle            M  Silver  AthensAUT
# 2  100m freestyle for sailors            M  Bronze  AthensGRE
# 3  100m freestyle for sailors            M    Gold  AthensGRE
# 4  100m freestyle for sailors            M  Silver  AthensGRE

# %%
# Drop the 'newcol' and 'Event_gender' columns
oo.drop(['newcol', 'Event_gender'], axis='columns', inplace=True)

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event   Medal
# ...

# %% [markdown]
# # Appending pandas Series

# %%
# Import pandas
import pandas as pd

# Load 'sales-jan-2015.csv' into a DataFrame: jan
jan = pd.read_csv('./data/sales-jan-2015.csv', parse_dates=True , index_col='Date')

# Load 'sales-feb-2015.csv' into a DataFrame: feb
feb = pd.read_csv('./data/sales-feb-2015.csv', parse_dates=True, index_col='Date')

# Load 'sales-mar-2015.csv' into a DataFrame: mar
mar = pd.read_csv('./data/sales-mar-2015.csv', parse_dates=True, index_col='Date')

feb.head()
# Out:
#                        Company   Product  Units
# Date
# 2015-02-26 08:57:45  Streeplex   Service      4
# 2015-02-16 12:09:19      Hooli  Software     10
# 2015-02-03 14:14:18    Initech  Software     13
# 2015-02-02 08:33:01      Hooli  Software      3
# 2015-02-25 00:29:00    Initech   Service     10

# %%
# Extract the 'Units' column from jan: jan_units
jan_units = jan['Units']

# Extract the 'Units' column from feb: feb_units
feb_units = feb['Units']

# Extract the 'Units' column from mar: mar_units
mar_units = mar['Units']

# Append feb_units and then mar_units to jan_units: quarter1
quarter1 = jan_units.append(feb_units).append(mar_units)


# Print the first slice from quarter1
print(quarter1.loc['jan 27, 2015':'feb 2, 2015'])

type(quarter1)
# Out:
# Date
# 2015-01-27 07:11:55    18
# 2015-02-02 08:33:01     3
# 2015-02-02 20:54:49     9
# Name: Units, dtype: int64
# pandas.core.series.Series

# %%
# Print the second slice from quarter1
print(quarter1.loc['feb 26, 2015':'mar 7, 2015'])

# Compute & print total sales in quarter1
print(quarter1.sum())
# Out:
# Date
# 2015-02-26 08:57:45     4
# 2015-02-26 08:58:51     1
# 2015-03-06 10:11:45    17
# 2015-03-06 02:03:56    17
# Name: Units, dtype: int64
# 642
